# %%
pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9677 sha256=37d7d30a5ca6d8b89b3466789081a51c7216d8b50f7a600f45ed60bc8d994413
#   Stored in directory: c:\users\anyfo\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m wget https://www.muratkoklu.com/datasets/vtdhnd12.php -o pistachio.zip
# Out:
# Saved under pistachio.zip

# %%
#extract zip
import zipfile
unzip_files = zipfile.ZipFile('pistachio.zip','r')
unzip_files.extractall('extracted_pis')

# %%
## identify

# %%
import os

path ="extracted_pis"
dir_list = os.listdir(path)

print("Files and directories in'",path,"' :")

#print the list
print(dir_list)
# Out:
# Files and directories in' extracted_pis ' :
# ['Pistachio_Image_Dataset']

# %%
def fast_scandir(dirname):
    subfolders = [f.path for f in os.scandir(dirname) if f.is_dir()]
    for dirname in list(subfolders):
        subfolders.extend(fast_scandir(dirname))
    return subfolders

fast_scandir(path)
# Out:
# ['extracted_pis\\Pistachio_Image_Dataset',
#  'extracted_pis\\Pistachio_Image_Dataset\\Pistachio_16_Features_Dataset',
#  'extracted_pis\\Pistachio_Image_Dataset\\Pistachio_28_Features_Dataset',
#  'extracted_pis\\Pistachio_Image_Dataset\\Pistachio_Image_Dataset',
#  'extracted_pis\\Pistachio_Image_Dataset\\Pistachio_Image_Dataset\\Kirmizi_Pistachio',
#  'extracted_pis\\Pistachio_Image_Dataset\\Pistachio_Image_Dataset\\Siirt_Pistachio']

# %%
os.listdir('extracted_pis/Pistachio_Image_Dataset/Pistachio_16_Features_Dataset')
# Out:
# ['Pistachio_16_Features_Dataset.arff',
#  'Pistachio_16_Features_Dataset.xls',
#  'Pistachio_16_Features_Dataset.xlsx',
#  'Pistachio_16_Features_Dataset_Citation_Request.txt']

# %%
os.listdir('extracted_pis/Pistachio_Image_Dataset/Pistachio_28_Features_Dataset')
# Out:
# ['Pistachio_28_Features_Dataset.arff',
#  'Pistachio_28_Features_Dataset.xls',
#  'Pistachio_28_Features_Dataset.xlsx',
#  'Pistachio_28_Features_Dataset_Citation_Request.txt']

# %%
os.listdir('extracted_pis/Pistachio_Image_Dataset/Pistachio_Image_Dataset/Kirmizi_Pistachio')
# Out:
# ['kirmizi (1).jpg',
#  'kirmizi (10).jpg',
#  'kirmizi (11).jpg',
#  'kirmizi (12).jpg',
#  'kirmizi (13).jpg',
#  'kirmizi (14).jpg',
#  'kirmizi (15).jpg',
#  'kirmizi (16).jpg',
#  'kirmizi (17).jpg',
#  'kirmizi (18).jpg',
#  'kirmizi (19).jpg',
#  'kirmizi (2).jpg',
#  'kirmizi (20).jpg',
#  'kirmizi (21).jpg',
#  'kirmizi (22).jpg',
#  'kirmizi (23).jpg',
#  'kirmizi (24).jpg',
#  'kirmizi (25).jpg',
#  'kirmizi (26).jpg',
#  'kirmizi (27).jpg',
#  'kirmizi (28).jpg',
#  'kirmizi (29).jpg',
#  'kirmizi (3).jpg',
#  'kirmizi (30).jpg',
#  'kirmizi (31).jpg',
#  'kirmizi (32).jpg',
#  'kirmizi (33).jpg',
#  'kirmizi (34).jpg',
#  'kirmizi (35).jpg',
#  'kirmizi (36).jpg',
#  'kirmizi (37).jpg',
#  'kirmizi (38).jpg',
#  'kirmizi (39).jpg',
#  'kirmizi (4).jpg',
#  'kirmizi (40).jpg',
#  'kirmizi (41).jpg',
#  'kirmizi (42).jpg',
#  'kirmizi (43).jpg',
#  'kirmizi (44).jpg',
#  'kirmizi (45).jpg',
#  'kirmizi (46).jpg',
#  'kirmizi (47).jpg',
#  'kirmizi (48).jpg',
# ...

# %%
os.listdir('extracted_pis/Pistachio_Image_Dataset/Pistachio_Image_Dataset/Siirt_Pistachio')
# Out:
# ['siirt (1).jpg',
#  'siirt (10).jpg',
#  'siirt (11).jpg',
#  'siirt (12).jpg',
#  'siirt (13).jpg',
#  'siirt (14).jpg',
#  'siirt (15).jpg',
#  'siirt (16).jpg',
#  'siirt (17).jpg',
#  'siirt (18).jpg',
#  'siirt (19).jpg',
#  'siirt (2).jpg',
#  'siirt (20).jpg',
#  'siirt (21).jpg',
#  'siirt (22).jpg',
#  'siirt (23).jpg',
#  'siirt (24).jpg',
#  'siirt (25).jpg',
#  'siirt (26).jpg',
#  'siirt (27).jpg',
#  'siirt (28).jpg',
#  'siirt (29).jpg',
#  'siirt (3).jpg',
#  'siirt (30).jpg',
#  'siirt (31).jpg',
#  'siirt (32).jpg',
#  'siirt (33).jpg',
#  'siirt (34).jpg',
#  'siirt (35).jpg',
#  'siirt (36).jpg',
#  'siirt (37).jpg',
#  'siirt (38).jpg',
#  'siirt (39).jpg',
#  'siirt (4).jpg',
#  'siirt (40).jpg',
#  'siirt (41).jpg',
#  'siirt (42).jpg',
#  'siirt (43).jpg',
#  'siirt (44).jpg',
#  'siirt (45).jpg',
#  'siirt (46).jpg',
#  'siirt (47).jpg',
#  'siirt (48).jpg',
#  'siirt (49).jpg',
#  'siirt (5).jpg',
#  'siirt (50).jpg',
#  'siirt (6).jpg',
# ...

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.5.2-cp39-cp39-win_amd64.whl (7.2 MB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached fonttools-4.33.3-py3-none-any.whl (930 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#show image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image = mpimg.imread('extracted_pis/Pistachio_Image_Dataset/Pistachio_Image_Dataset/Kirmizi_Pistachio/kirmizi 59.jpg')
print (image.shape)
plt.imshow(image)
# Out:
# (600, 600, 3)

# %%
## define path

class1 = 'extracted_pis/Pistachio_Image_Dataset/Pistachio_Image_Dataset/Kirmizi_Pistachio'
class2 = 'extracted_pis/Pistachio_Image_Dataset/Pistachio_Image_Dataset/Siirt_Pistachio'
class_dict ={'Kirmizi':len(os.listdir(class1)), 'Siirt' : len(os.listdir(class2))}

print(class_dict)
# Out:
# {'Kirmizi': 1232, 'Siirt': 916}

# %%
#show 9 random
import os
import random
from PIL import Image
filenames = random.sample(os.listdir(class1),9)
print(filenames)
# Out:
# ['kirmizi 57.jpg', 'kirmizi 286.jpg', 'kirmizi 888.jpg', 'kirmizi 936.jpg', 'kirmizi 676.jpg', 'kirmizi 740.jpg', 'kirmizi 257.jpg', 'kirmizi 81.jpg', 'kirmizi 550.jpg']

# %%
file_name = filenames
file_num = [1,2,3,4,5,6,7,8,9]
dictionary = dict(zip(file_name,file_num))

print(dictionary)
# Out:
# {'kirmizi 57.jpg': 1, 'kirmizi 286.jpg': 2, 'kirmizi 888.jpg': 3, 'kirmizi 936.jpg': 4, 'kirmizi 676.jpg': 5, 'kirmizi 740.jpg': 6, 'kirmizi 257.jpg': 7, 'kirmizi 81.jpg': 8, 'kirmizi 550.jpg': 9}

# %%
## define new path && show  image
for key in dictionary:
    path = os.path.join(class1,key)
    image = mpimg.imread(path)
    print(image.shape)
    plt.subplot(3,3,dictionary[key])
    plt.imshow(image)

plt.show()
# Out:
# (600, 600, 3)
# (600, 600, 3)
# (600, 600, 3)
# (600, 600, 3)
# (600, 600, 3)
# (600, 600, 3)
# (600, 600, 3)
# (600, 600, 3)
# (600, 600, 3)

# %%
##diagram
names = list(class_dict.keys())
values = list(class_dict.values())

plt.bar(range(len(class_dict)),values, tick_label=names)
plt.show()

# %%
plt.pie(values,labels = names)
plt.show()
